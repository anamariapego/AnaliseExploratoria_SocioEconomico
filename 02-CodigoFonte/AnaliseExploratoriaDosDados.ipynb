# %% [markdown]
# <h1 style="text-align: center; color: #00A859"> Projeto Análise Exploratória de Dados
# Socioeconômicos </h1>

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #EDF8FD; color: #4F4F4F;" ><font size="3">
#     <h3>Project Description:</h3>
#
# A análise de dados socioeconômicos é uma atividade fundamental para qualquer empresa que busca compreender como as mudanças no cenário podem impactar suas estratégias corporativas e, consequentemente, auxilia na tomada de decisões mais informadas e assertivas.
#
# A descrição dos dados utilizados estão no arquivo <a style="text-decoration: none;" href="https://github.com/anamariapego/AnaliseExploratoria_SocioEconomico/blob/main/01-Documentacao/DictionaryData.ipynb">DictionaryData.ipynb</a>  na pasta 01-Documentacao.
# </font>
# </div>

# %% [markdown]
# <font size="5"><a id="sumario"><bold>Summary</bold></a></font>
# ***
# >1. [Importação das Bibliotecas](#ses1)
# >2. [Funções](#ses2)
# >3. [Carregando os Dados](#ses3)
# >4. [Limpeza/Processamento dos Dados](#ses4)
# >5. [Análisando os dados e Respondendo as Perguntas](#ses5)

# %% [markdown]
# <font size="5"><a id="ses1"><bold>Imports</bold></a></font>
#
# [Voltar](#sumario)
#
# <h3 style="color: #00A859">Section Description</h3>
#
# Importações das bibliotecas utilizadas para o desenvolvimento desse notebook e algumas configurações de saídas de códigos.

# %%
# Imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import zipfile
from glob import glob
from sklearn.impute import SimpleImputer

# %%
# Versão da Linguagem Python

from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
print("")

# Versões de pacotes utilizados 

# %reload_ext watermark
# %watermark -a "Data Scientist" --iversions
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.10.8
#
# Author: Data Scientist
#
# seaborn   : 0.12.1
# matplotlib: 3.6.2
# numpy     : 1.22.4
# pandas    : 1.5.2

# %%
# Para ignorar mensagens de alertas 

warnings.filterwarnings('ignore')

# %config Completer.use_jedi = False

# Visualizar todas as colunas do dataset

pd.set_option('display.max_columns', None)

# %% [markdown]
# <font size="5"><a id="ses2"><bold>Funções</bold></a></font>
#
# [Voltar](#sumario)
#
# <h3 style="color: #00A859">Section Description</h3>
#
# Funções desenvolvidas para facilitar a análise.

# %%
def clean_columns (x: pd.DataFrame):
    """
    Função para limpar e organizar os nomes das colunas
    
    x: dataframe no qual os nomes das colunas serão limpadas 
    
    """
    if isinstance(x, pd.DataFrame):
        x.columns = x.columns.str.replace(" ", "_").str.title().str.strip().str.lower()
    
    else:
        raise Exception('O tipo da variável deve ser pandas.core.frame.DataFrame. O tipo dado foi: {}'.format(type(x)))

# %%
def rename_columns(df: pd.DataFrame, new_columns: list):
    """
    Função para renomear as colunas de um DataFrame de acordo com uma lista de nomes definidas
    
    df: dataframe no qual as colunas serão renomeadas
    new_columns: lista com os novos nomes das colunas, na ordem desejada
    
    """
    if isinstance(df, pd.DataFrame):
        if len(new_columns) == len(df.columns):
            df.columns = new_columns
        else:
            raise ValueError('A lista de novos nomes deve ter o mesmo número de elementos que o número de colunas do DataFrame')
    else:
        raise TypeError('O tipo da variável deve ser pandas.core.frame.DataFrame. O tipo dado foi: {}'.format(type(df)))

# %%
def plot_chart(data, chart_type, x_column, y_column, color=None, title='', xlabel='', ylabel=''):
    
    """
    Função com configurações gerais para plotar gráfico
    
    """
    
    plt.figure(figsize=(12, 6))
    chart_func = getattr(sns, chart_type)
    
    if color:
        chart_func(data=data, x=x_column, y=y_column, color=color)
    else:
        chart_func(data=data, x=x_column, y=y_column)
    
    plt.title(title, loc='left', size=15, pad=20)
    plt.xlabel(xlabel, size=12)
    plt.ylabel(ylabel, size=12)
    sns.despine()
    plt.show()

# %%
def format_dataframe(df, titulo='', column_align='', color=''):
    
    styles = [
        dict(selector="caption", props=[("font-size", "130%"),
                                         ("font-weight", "bold")]),
        {'selector': 'th', 'props': [('text-align', 'left')]},
    ]
    df = df.style.set_caption(titulo).set_table_styles(styles).format({
        column_align: lambda x: '<div style="text-align: left">{}</div>'.format(x)
    })
    return df

# %% [markdown]
# <font size="5"><a id="ses3"><bold>Carregamento</bold></a></font>
#
# [Voltar](#sumario)
#
# <h3 style="color: #00A859">Section Description</h3>
#
# Carregando os dados.

# %%
# Caminho dos dados 

path = r"C:/Projetos/AnaliseExploratoria_SocioEconomico/02-CodigoFonte/00-DataSets/"

# %%
data_socio = pd.read_csv(path + 'dataset.csv')
data_socio.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.518            0.258
# 1                      0.850            0.584            0.237
# 2                      0.707            0.618            0.275
# 3                      0.731            0.611            0.267
# 4                      0.776            0.710            0.268

# %% [markdown]
# <font size="5"><a id="ses4"><bold>Processamento/Limpeza dos dados</bold></a></font>
#
# [Voltar](#sumario)
#
# <h3 style="color: #00A859">Section Description</h3>
#
# Sessão para fazer os processamentos e limpezas necessárias dos dados antes das análises.

# %%
# Dimensão do dataset (linhas e colunas)

data_socio.shape
# Out:
# (1949, 11)

# %%
# Limpando e padronizando os nomes das colunas 

clean_columns(data_socio)

# %%
# estatística básica

data_socio.describe()
# Out:
#               year  life_ladder  log_gdp_per_capita  social_support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# 25%                           58.685000                      0.647000
# 50%                           65.200000                      0.763000
# 75%                           68.590000                      0.856000
# max                           77.100000                      0.985000
#
#         generosity  perceptions_of_corruption  positive_affect  \
# count  1860.000000                1839.000000      1927.000000
# mean      0.000103                   0.747125         0.710003
# std       0.162215                   0.186789         0.107100
# min      -0.335000                   0.035000         0.322000
# 25%      -0.113000                   0.690000         0.625500
# 50%      -0.025500                   0.802000         0.722000
# 75%       0.091000                   0.872000         0.799000
# max       0.698000                   0.983000         0.944000
#
#        negative_affect
# count      1933.000000
# mean          0.268544
# std           0.085168
# min           0.083000
# 25%           0.206000
# 50%           0.258000
# 75%           0.320000
# max           0.705000

# %%
# Valores ausentes

data_socio[data_socio.isnull().any(axis=1)]
# Out:
#      country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 25        Algeria  2010        5.464               9.287             NaN
# 28        Algeria  2014        6.355               9.335           0.818
# 29        Algeria  2016        5.341               9.362           0.749
# 66      Australia  2005        7.341              10.659           0.968
# 110       Bahrain  2012        5.027              10.716           0.911
# ...           ...   ...          ...                 ...             ...
# 1908        Yemen  2007        4.477               8.214           0.825
# 1916        Yemen  2016        3.826               7.715           0.775
# 1917        Yemen  2017        3.254               7.578           0.790
# 1918        Yemen  2018        3.058                 NaN           0.789
# 1919        Yemen  2019        4.197                 NaN           0.870
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# 25                               64.50                         0.593
# 28                               65.14                           NaN
# 29                               65.50                           NaN
# 66                               71.40                         0.935
# 110                              66.86                         0.682
# ...                                ...                           ...
# 1908                             53.40                         0.673
# 1916                             55.10                         0.533
# 1917                             55.90                         0.595
# 1918                             56.70                         0.553
# 1919                             57.50                         0.651
#
#       generosity  perceptions_of_corruption  positive_affect  negative_affect
# 25        -0.205                      0.618              NaN              NaN
# 28           NaN                        NaN            0.626            0.177
# 29           NaN                        NaN            0.661            0.377
# 66           NaN                      0.390            0.843            0.238
# 110          NaN                      0.438            0.589            0.381
# ...          ...                        ...              ...              ...
# 1908       0.011                        NaN            0.592            0.379
# 1916      -0.151                        NaN            0.469            0.228
# 1917      -0.147                        NaN            0.455            0.295
# 1918         NaN                      0.793            0.461            0.315
# 1919         NaN                      0.798            0.543            0.213
#
# [241 rows x 11 columns]

# %%
# Porcentagem por coluna de valores ausentes

percent_missing = data_socio.isnull().sum() * 100 / len(data_socio)

missing_value_df = pd.DataFrame({'qtd_missing': data_socio.isnull().sum(),
                                 'percent_missing': percent_missing,
                                 'column_type': data_socio.dtypes}
                               ).reset_index().rename(columns={'index': 'column_name'})

missing_value_df
# Out:
#                          column_name  qtd_missing  percent_missing column_type
# 0                       country_name            0         0.000000      object
# 1                               year            0         0.000000       int64
# 2                        life_ladder            0         0.000000     float64
# 3                 log_gdp_per_capita           36         1.847101     float64
# 4                     social_support           13         0.667009     float64
# 5   healthy_life_expectancy_at_birth           55         2.821960     float64
# 6       freedom_to_make_life_choices           32         1.641868     float64
# 7                         generosity           89         4.566444     float64
# 8          perceptions_of_corruption          110         5.643920     float64
# 9                    positive_affect           22         1.128784     float64
# 10                   negative_affect           16         0.820934     float64

# %% [markdown]
# <h3 style="color: #cca002"><strong>Observação sobre os valores ausentes:</strong></h3>
#
# Como os as porcentagem de valores ausentes são baixos, então será feita uma tratativa de subtituir os valores NAs pela ,média da coluna.

# %%
# Substituindo os NAs pela média de cada coluna 

imp_object = SimpleImputer(missing_values=np.nan, strategy='mean')
colunas_object = data_socio.select_dtypes(include=['float64']).columns

data_socio[colunas_object] = imp_object.fit_transform(data_socio[colunas_object])
data_socio.head()
# Out:
#   country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    healthy_life_expectancy_at_birth  freedom_to_make_life_choices  generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    perceptions_of_corruption  positive_affect  negative_affect
# 0                      0.882            0.518            0.258
# 1                      0.850            0.584            0.237
# 2                      0.707            0.618            0.275
# 3                      0.731            0.611            0.267
# 4                      0.776            0.710            0.268

# %%
# matriz de correlação 

data_socio[colunas_object].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_80153_row0_col0, #T_80153_row1_col1, #T_80153_row2_col2, #T_80153_row3_col3, #T_80153_row4_col4, #T_80153_row5_col5, #T_80153_row6_col6, #T_80153_row7_col7, #T_80153_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_80153_row0_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_80153_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_80153_row0_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_80153_row0_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_80153_row0_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_80153_row0_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_80153_row0_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_80153_row0_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_80153_row1_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_80153_row1_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_80153_row1_col3 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_80153_row1_col4 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_80153_row1_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_80153_row1_col6, #T_80153_row4_col8, #T_80153_row8_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_80153_row1_col7 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_80153_row1_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_80153_row2_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_80153_row2_col1 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_80153_row2_col3 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_80153_row2_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_80153_row2_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_80153_row2_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_80153_row2_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_80153_row2_col8, #T_80153_row4_col6, #T_80153_row6_col0, #T_80153_row6_col1, #T_80153_row6_col3, #T_80153_row6_col4, #T_80153_row6_col5, #T_80153_row8_col2, #T_80153_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_80153_row3_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_80153_row3_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_80153_row3_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_80153_row3_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_80153_row3_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_80153_row3_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_80153_row3_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_80153_row3_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_80153_row4_col0 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_80153_row4_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_80153_row4_col2 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_80153_row4_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_80153_row4_col5, #T_80153_row6_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_80153_row4_col7 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_80153_row5_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_80153_row5_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_80153_row5_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_80153_row5_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_80153_row5_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_80153_row5_col6, #T_80153_row8_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_80153_row5_col7 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_80153_row5_col8 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_80153_row6_col2, #T_80153_row7_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_80153_row6_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_80153_row7_col0 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_80153_row7_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_80153_row7_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_80153_row7_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_80153_row7_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_80153_row7_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_80153_row7_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_80153_row8_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_80153_row8_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_80153_row8_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_80153_row8_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# </style>
# <table id="T_80153">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80153_level0_col0" class="col_heading level0 col0" >life_ladder</th>
#       <th id="T_80153_level0_col1" class="col_heading level0 col1" >log_gdp_per_capita</th>
#       <th id="T_80153_level0_col2" class="col_heading level0 col2" >social_support</th>
#       <th id="T_80153_level0_col3" class="col_heading level0 col3" >healthy_life_expectancy_at_birth</th>
#       <th id="T_80153_level0_col4" class="col_heading level0 col4" >freedom_to_make_life_choices</th>
#       <th id="T_80153_level0_col5" class="col_heading level0 col5" >generosity</th>
#       <th id="T_80153_level0_col6" class="col_heading level0 col6" >perceptions_of_corruption</th>
#       <th id="T_80153_level0_col7" class="col_heading level0 col7" >positive_affect</th>
#       <th id="T_80153_level0_col8" class="col_heading level0 col8" >negative_affect</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80153_level0_row0" class="row_heading level0 row0" >life_ladder</th>
#       <td id="T_80153_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_80153_row0_col1" class="data row0 col1" >0.78</td>
#       <td id="T_80153_row0_col2" class="data row0 col2" >0.71</td>
#       <td id="T_80153_row0_col3" class="data row0 col3" >0.74</td>
#       <td id="T_80153_row0_col4" class="data row0 col4" >0.53</td>
#       <td id="T_80153_row0_col5" class="data row0 col5" >0.19</td>
#       <td id="T_80153_row0_col6" class="data row0 col6" >-0.42</td>
#       <td id="T_80153_row0_col7" class="data row0 col7" >0.53</td>
#       <td id="T_80153_row0_col8" class="data row0 col8" >-0.30</td>
#     </tr>
#     <tr>
#       <th id="T_80153_level0_row1" class="row_heading level0 row1" >log_gdp_per_capita</th>
#       <td id="T_80153_row1_col0" class="data row1 col0" >0.78</td>
#       <td id="T_80153_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_80153_row1_col2" class="data row1 col2" >0.68</td>
#       <td id="T_80153_row1_col3" class="data row1 col3" >0.83</td>
#       <td id="T_80153_row1_col4" class="data row1 col4" >0.36</td>
#       <td id="T_80153_row1_col5" class="data row1 col5" >-0.00</td>
#       <td id="T_80153_row1_col6" class="data row1 col6" >-0.33</td>
#       <td id="T_80153_row1_col7" class="data row1 col7" >0.30</td>
#       <td id="T_80153_row1_col8" class="data row1 col8" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_80153_level0_row2" class="row_heading level0 row2" >social_support</th>
#       <td id="T_80153_row2_col0" class="data row2 col0" >0.71</td>
#       <td id="T_80153_row2_col1" class="data row2 col1" >0.68</td>
#       <td id="T_80153_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_80153_row2_col3" class="data row2 col3" >0.61</td>
#       <td id="T_80153_row2_col4" class="data row2 col4" >0.41</td>
#       <td id="T_80153_row2_col5" class="data row2 col5" >0.07</td>
#       <td id="T_80153_row2_col6" class="data row2 col6" >-0.22</td>
#       <td id="T_80153_row2_col7" class="data row2 col7" >0.43</td>
#       <td id="T_80153_row2_col8" class="data row2 col8" >-0.40</td>
#     </tr>
#     <tr>
#       <th id="T_80153_level0_row3" class="row_heading level0 row3" >healthy_life_expectancy_at_birth</th>
#       <td id="T_80153_row3_col0" class="data row3 col0" >0.74</td>
#       <td id="T_80153_row3_col1" class="data row3 col1" >0.83</td>
#       <td i

# %% [markdown]
# <span style="color: #cca002">**Obs:**</span>  Antes de iniciar as respostas das perguntas, os nomes das colunas serão remomeadas para melhor compreensão e visualização dos gráficos.

# %%
# Definindo os nomes das colunas 

columns_names = ['Pais', 'Ano', 'IndicadorNivelVida', 'PIB_Per_Capita', 'SuporteSocial', 'ExpectativaVida', 
                 'IndicadorLiberdade', 'IndicadorGenerosidade', 'IndicadorCorrupcao', 'IndicadorEmocoesPositivas',
                 'IndicadorEmocoesNegativas']

# %%
# Renomeando as colunas

rename_columns(data_socio, columns_names)

# %% [markdown]
# <font size="5"><a id="ses5"><bold>Análisando os dados e Respondendo as Perguntas</bold></a></font>
#
# [Voltar](#sumario)
#
# <h3 style="color: #00A859">Section Description</h3>
#
# Sessão para fazer as análises para responder as perguntas levantadas.

# %% [markdown]
# <h3><strong>Quais anos aconteceu as pesquisas?</strong></h3>

# %%
print("""
    As pesquisas foram realizadas entre os anos de {} à {}.
    """.format(data_socio['Ano'].min(), data_socio['Ano'].min()))
# Out:
#     As pesquisas foram realizadas entre os anos de 2005 à 2005.

# %% [markdown]
# <h3><strong>Quantos países participaram da pesquisa? </strong></h3>

# %%
print("""
    Participaram da pesquisa {} país, inclusive o Brasil.
    """.format(len(data_socio['Pais'].drop_duplicates())))
# Out:
#     Participaram da pesquisa 166 país, inclusive o Brasil.

# %% [markdown]
# <h3><strong>Quantidade de registros por anos</strong></h3>

# %%
# Plotando o gráfico

plot_chart(data_socio, 'countplot', 'Ano', None, color="#006373", 
           title='Quantidade de registro durante os anos', xlabel='Anos', ylabel='Quantidade')

# %% [markdown]
# <h3><strong>O aumento do PIB per capita de um país afeta positivamente a expectativa de vida dos cidadãos ao nascer? Qual a correlação entre essas duas variáveis?</strong></h3>

# %%
# Configurando para fazer as médias por país

df_mean = data_socio.loc[:, data_socio.columns != 'Ano'].groupby('Pais', as_index = False).mean()
df_mean.head()
# Out:
#           Pais  IndicadorNivelVida  PIB_Per_Capita  SuporteSocial  \
# 0  Afghanistan            3.594667        7.650833       0.508417
# 1      Albania            5.019385        9.384385       0.716231
# 2      Algeria            5.389875        9.328875       0.804694
# 3       Angola            4.420250        8.990000       0.738250
# 4    Argentina            6.310133       10.033800       0.904400
#
#    ExpectativaVida  IndicadorLiberdade  IndicadorGenerosidade  \
# 0        52.266667            0.518167               0.070083
# 1        67.546154            0.662923              -0.082692
# 2        65.290000            0.575014              -0.108224
# 3        53.550000            0.456250              -0.088250
# 4        67.900000            0.768200              -0.159867
#
#    IndicadorCorrupcao  IndicadorEmocoesPositivas  IndicadorEmocoesNegativas
# 0            0.843333                   0.548667                   0.326500
# 1            0.869385                   0.653846                   0.299231
# 2            0.705031                   0.621125                   0.263068
# 3            0.866750                   0.613500                   0.351250
# 4            0.842067                   0.833467                   0.284000

# %%
# Matriz de correlação entre o PIB_Per_Capita e Expectativa de vida

df_mean[['PIB_Per_Capita','ExpectativaVida']].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_e43aa_row0_col0, #T_e43aa_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e43aa_row0_col1, #T_e43aa_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e43aa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e43aa_level0_col0" class="col_heading level0 col0" >PIB_Per_Capita</th>
#       <th id="T_e43aa_level0_col1" class="col_heading level0 col1" >ExpectativaVida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e43aa_level0_row0" class="row_heading level0 row0" >PIB_Per_Capita</th>
#       <td id="T_e43aa_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_e43aa_row0_col1" class="data row0 col1" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_e43aa_level0_row1" class="row_heading level0 row1" >ExpectativaVida</th>
#       <td id="T_e43aa_row1_col0" class="data row1 col0" >0.83</td>
#       <td id="T_e43aa_row1_col1" class="data row1 col1" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotando o gráfico

plot_chart(df_mean, 'scatterplot', 'ExpectativaVida', 'PIB_Per_Capita', color="#006373", 
           title='Relação entre o PIB Per Capita e a Expectativa de Vida', xlabel='Expectativa de Vida',
           ylabel='PIB Per Capita')

# %% [markdown]
# <h3 style="color: #cca002"><strong>Observações:</strong></h3>
#
# Sim, pelo gráfico percebe-se que há uma correlação positiva entre as variáveis. Quando o PIB Per Capita aumenta a expectativa de vida também tende a aumenta também.

# %% [markdown]
# <h3><strong>Existe uma correlação entre a escala de vida e a conscientização do público em geral sobre a corrupção nos negócios e no governo? Qual a correlação entre essas duas variáveis?</strong></h3>

# %%
# Matriz de correlação entre o indicador de corrupção e expectativa de vida

df_mean[['IndicadorCorrupcao','IndicadorNivelVida']].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_a1fee_row0_col0, #T_a1fee_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a1fee_row0_col1, #T_a1fee_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a1fee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1fee_level0_col0" class="col_heading level0 col0" >IndicadorCorrupcao</th>
#       <th id="T_a1fee_level0_col1" class="col_heading level0 col1" >IndicadorNivelVida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1fee_level0_row0" class="row_heading level0 row0" >IndicadorCorrupcao</th>
#       <td id="T_a1fee_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a1fee_row0_col1" class="data row0 col1" >-0.41</td>
#     </tr>
#     <tr>
#       <th id="T_a1fee_level0_row1" class="row_heading level0 row1" >IndicadorNivelVida</th>
#       <td id="T_a1fee_row1_col0" class="data row1 col0" >-0.41</td>
#       <td id="T_a1fee_row1_col1" class="data row1 col1" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotando o gráfico

plot_chart(df_mean, 'scatterplot', 'IndicadorCorrupcao', 'IndicadorNivelVida', color="#006373", 
           title='Relação entre a Corrupção e a Escala de Vida', xlabel='Indicador de Corrupção',
           ylabel='Escala de Vida')

# %% [markdown]
# <h3 style="color: #cca002"><strong>Observações:</strong></h3>
#
# Sim, existe um correlação entre a escala de vida e o índice de corrupção. Nesse caso, uma correlação negativa pois quanto maior é o índice de corrupção menor é a expectativa de vida.

# %% [markdown]
# <h3>O aumento na escala de vida tem algum efeito na média de felicidade entre o público em geral? Qual a correlação entre essas duas variáveis?<qh3>

# %%
# Matriz de correlação entre o indicador de emoções e escala de vida

df_mean[['IndicadorEmocoesPositivas','IndicadorNivelVida']].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_030be_row0_col0, #T_030be_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_030be_row0_col1, #T_030be_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_030be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_030be_level0_col0" class="col_heading level0 col0" >IndicadorEmocoesPositivas</th>
#       <th id="T_030be_level0_col1" class="col_heading level0 col1" >IndicadorNivelVida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_030be_level0_row0" class="row_heading level0 row0" >IndicadorEmocoesPositivas</th>
#       <td id="T_030be_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_030be_row0_col1" class="data row0 col1" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_030be_level0_row1" class="row_heading level0 row1" >IndicadorNivelVida</th>
#       <td id="T_030be_row1_col0" class="data row1 col0" >0.57</td>
#       <td id="T_030be_row1_col1" class="data row1 col1" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plotando o gráfico

plot_chart(df_mean, 'scatterplot', 'IndicadorEmocoesPositivas', 'IndicadorNivelVida', color="#006373", 
           title='Relação entre o Emoções Positivas e a Escala de Vida', xlabel='Indicador de Emoções Positivas',
           ylabel='Escala de Vida')

# %% [markdown]
# <h3 style="color: #cca002"><strong>Observações:</strong></h3>
#
# Sim, quando maior é a a escala de vida maior é o índice de felicidade do público.

# %% [markdown]
# <h3> O país com o menor índice de suporte social tem maior percepção de corrupção em relação às empresas e ao governo no país?</h3>

# %%
# Buscando o país com menor índice de suporte 

df_mean.loc[df_mean['SuporteSocial'] == min(df_mean['SuporteSocial'])]
# Out:
#                         Pais  IndicadorNivelVida  PIB_Per_Capita  \
# 26  Central African Republic               3.515           6.961
#
#     SuporteSocial  ExpectativaVida  IndicadorLiberdade  IndicadorGenerosidade  \
# 26         0.4024           43.356              0.6804                  0.027
#
#     IndicadorCorrupcao  IndicadorEmocoesPositivas  IndicadorEmocoesNegativas
# 26               0.842                     0.5616                     0.3914

# %%
max(data_socio['SuporteSocial'])
# Out:
# 0.987

# %%
max(data_socio['IndicadorCorrupcao'])
# Out:
# 0.983

# %% [markdown]
# <h3 style="color: #cca002"><strong>Observações:</strong></h3>
#
# Buscamos o país que teve a menor média de suporte social durante os anos de pesquisas e esse país é o **Central African Republic** com um média de 0.40,  menos da metade do valor máxino de suporte social. E o indicador de corrupção do Central African Republic é **0.87**, muito próximo do maior indicador de corrupção.

# %% [markdown]
# <h3>Quais países apresentam os maiores e menores médias de indicadores de generosidade?</h3>

# %%
# Arredondando os valores
df_mean['IndicadorGenerosidade'] = df_mean['IndicadorGenerosidade'].apply(lambda x: "{:.2f}".format(x))

# Maiores países

df_max = df_mean.sort_values('IndicadorGenerosidade', 
                             ascending=False)[['Pais', 'IndicadorGenerosidade']].head(10)

df_max = df_max.rename(columns={"Pais": "Países", "IndicadorGenerosidade": "Indicador de Genorosidade"})

# Piores países 

df_min = df_mean.sort_values('IndicadorGenerosidade', 
                             ascending=False)[['Pais', 'IndicadorGenerosidade']].tail(10)

df_min = df_min.rename(columns={"Pais": "Países", "IndicadorGenerosidade": "Indicador de Genorosidade"})

# Formatando as tabelas

df_max = format_dataframe(df_max, "Países com as <span style = 'color: green'> melhores </span> médias de Generosidade", 
                 "Países", color= "#006373")

df_min = format_dataframe(df_min, "Países com as <span style = 'color: red'> piores </span> médias de Generosidade", 
                 "Países", color = '#fa4848')

# %%
from IPython.core.display import display, HTML

# converte as tabelas para HTML
df_max = df_max.to_html(index=False)
df_min = df_min.to_html(index=False)

# cria um código HTML com duas colunas
html_code = f'''
    <div style="display:flex; justify-content: space-between">
        <div style="width:50%;">
            {df_max}
        </div>
        <div style="width:50%;">
            {df_min}
        </div>
    </div>
'''

# exibe o HTML com as tabelas lado a lado
display(HTML(html_code))
# Out:
#     <div style="display:flex; justify-content: space-between">
#         <div style="width:50%;">
#             <style type="text/css">
# #T_1aec8 caption {
#   font-size: 130%;
#   font-weight: bold;
# }
# #T_1aec8 th {
#   text-align: left;
# }
# </style>
# <table id="T_1aec8">
#   <caption>Países com as <span style = 'color: green'> melhores </span> médias de Generosidade</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1aec8_level0_col0" class="col_heading level0 col0" >Países</th>
#       <th id="T_1aec8_level0_col1" class="col_heading level0 col1" >Indicador de Genorosidade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1aec8_level0_row0" class="row_heading level0 row0" >101</th>
#       <td id="T_1aec8_row0_col0" class="data row0 col0" ><div style="text-align: left">Myanmar</div></td>
#       <td id="T_1aec8_row0_col1" class="data row0 col1" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row1" class="row_heading level0 row1" >64</th>
#       <td id="T_1aec8_row1_col0" class="data row1 col0" ><div style="text-align: left">Indonesia</div></td>
#       <td id="T_1aec8_row1_col1" class="data row1 col1" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row2" class="row_heading level0 row2" >148</th>
#       <td id="T_1aec8_row2_col0" class="data row2 col0" ><div style="text-align: left">Thailand</div></td>
#       <td id="T_1aec8_row2_col1" class="data row2 col1" >0.38</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row3" class="row_heading level0 row3" >50</th>
#       <td id="T_1aec8_row3_col0" class="data row3 col0" ><div style="text-align: left">Gambia</div></td>
#       <td id="T_1aec8_row3_col1" class="data row3 col1" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row4" class="row_heading level0 row4" >58</th>
#       <td id="T_1aec8_row4_col0" class="data row4 col0" ><div style="text-align: left">Haiti</div></td>
#       <td id="T_1aec8_row4_col1" class="data row4 col1" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_1aec8_row5_col0" class="data row5 col0" ><div style="text-align: left">Bhutan</div></td>
#       <td id="T_1aec8_row5_col1" class="data row5 col1" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row6" class="row_heading level0 row6" >92</th>
#       <td id="T_1aec8_row6_col0" class="data row6 col0" ><div style="text-align: left">Malta</div></td>
#       <td id="T_1aec8_row6_col1" class="data row6 col1" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row7" class="row_heading level0 row7" >157</th>
#       <td id="T_1aec8_row7_col0" class="data row7 col0" ><div style="text-align: left">United Kingdom</div></td>
#       <td id="T_1aec8_row7_col1" class="data row7 col1" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row8" class="row_heading level0 row8" >79</th>
#       <td id="T_1aec8_row8_col0" class="data row8 col0" ><div style="text-align: left">Laos</div></td>
#       <td id="T_1aec8_row8_col1" class="data row8 col1" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_1aec8_level0_row9" class="row_heading level0 row9" >105</th>
#       <td id="T_1aec8_row9_col0" class="data row9 col0" ><div style="text-align: left">New Zealand</div></td>
#       <td id="T_1aec8_row9_col1" class="data row9 col1" >0.26</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div style="width:50%;">
#             <style type="text/css">
# #T_c6dee caption {
#   font-size: 130%;
#   font-weight: bold;
# }
# #T_c6dee th {
#   text-align: left;
# }
# </style>
# <table id="T_c6dee">
#   <caption>Países com as <span style = 'color: red'> piores </span> médias de Generosidade</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6dee_level0_col0" class="col_heading level0 col0" >Países</th>
#       <th id="T_c6dee_level0_col1" class="col_heading level0 col1" >Indicador de Genorosidade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6dee_level0_row0" class="row_heading level0 row0" >139</th>
#       <td id="T_c6dee_row0_col0" class="data row0 col0" ><div style="text-align: left">Sudan</div></td>
#       <td id="T_c6dee_row0_col1" class="data row0 col1" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_c6dee_row1_col0" class="data row1 col0" ><div style="text-align: left">Belgium</div></td>
#       <td id="T_c6dee_row1_col1" class="data row1 col1" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row2" class="row_heading level0 row2" >31</th>
#       <td id="T_c6dee_row2_col0" class="data row2 col0" ><div style="text-align: left">Comoros</div></td>
#       <td id="T_c6dee_row2_col1" class="data row2 col1" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row3" class="row_heading level0 row3" >131</th>
#       <td id="T_c6dee_row3_col0" class="data row3 col0" ><div style="text-align: left">Slovenia</div></td>
#       <td id="T_c6dee_row3_col1" class="data row3 col1" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row4" class="row_heading level0 row4" >33</th>
#       <td id="T_c6dee_row4_col0" class="data row4 col0" ><div style="text-align: left">Congo (Kinshasa)</div></td>
#       <td id="T_c6dee_row4_col1" class="data row4 col1" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row5" class="row_heading level0 row5" >146</th>
#       <td id="T_c6dee_row5_col0" class="data row5 col0" ><div style="text-align: left">Tajikistan</div></td>
#       <td id="T_c6dee_row5_col1" class="data row5 col1" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row6" class="row_heading level0 row6" >24</th>
#       <td id="T_c6dee_row6_col0" class="data row6 col0" ><div style="text-align: left">Cameroon</div></td>
#       <td id="T_c6dee_row6_col1" class="data row6 col1" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row7" class="row_heading level0 row7" >69</th>
#       <td id="T_c6dee_row7_col0" class="data row7 col0" ><div style="text-align: left">Italy</div></td>
#       <td id="T_c6dee_row7_col1" class="data row7 col1" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row8" class="row_heading level0 row8" >34</th>
#       <td id="T_c6dee_row8_col0" class="data row8 col0" ><div style="text-align: left">Costa Rica</div></td>
#       <td id="T_c6dee_row8_col1" class="data row8 col1" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c6dee_level0_row9" class="row_heading level0 row9" >110</th>
#       <td id="T_c6dee_row9_col0" class="data row9 col0" ><div style="text-align: left">North Macedonia</div></td>
#       <td id="T_c6dee_row9_col1" class="data row9 col1" >-0.00</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>

# %% [markdown]
# <h3>Quais são os países com os maiores e menores médias de indicadores de corrupção?</h3>

# %%
# Arredondando os valores
df_mean['IndicadorCorrupcao'] = df_mean['IndicadorCorrupcao'].apply(lambda x: "{:.2f}".format(x))

# Maiores países

df_max = df_mean.sort_values('IndicadorCorrupcao', 
                             ascending=False)[['Pais', 'IndicadorCorrupcao']].head(10)

df_max = df_max.rename(columns={"Pais": "Países", "IndicadorCorrupcao": "Indicador de Corrupção"})

# Piores países 

df_min = df_mean.sort_values('IndicadorCorrupcao', 
                             ascending=False)[['Pais', 'IndicadorCorrupcao']].tail(10)

df_min = df_min.rename(columns={"Pais": "Países", "IndicadorCorrupcao": "Indicador de Corrupção"})

# Formatando as tabelas

df_max = format_dataframe(df_max, "Países com as <span style = 'color: green'> melhores </span> médias de Corrupção", 
                 "Países", color= "#006373")

df_min = format_dataframe(df_min, "Países com as <span style = 'color: red'> piores </span> médias de Corrupção", 
                 "Países", color = '#fa4848')

# %%
from IPython.core.display import display, HTML

# converte as tabelas para HTML
df_max = df_max.to_html(index=False)
df_min = df_min.to_html(index=False)

# cria um código HTML com duas colunas
html_code = f'''
    <div style="display:flex; justify-content: space-between">
        <div style="width:50%;">
            {df_max}
        </div>
        <div style="width:50%;">
            {df_min}
        </div>
    </div>
'''

# exibe o HTML com as tabelas lado a lado
display(HTML(html_code))
# Out:
#     <div style="display:flex; justify-content: space-between">
#         <div style="width:50%;">
#             <style type="text/css">
# #T_5422c caption {
#   font-size: 130%;
#   font-weight: bold;
# }
# #T_5422c th {
#   text-align: left;
# }
# </style>
# <table id="T_5422c">
#   <caption>Países com as <span style = 'color: green'> melhores </span> médias de Corrupção</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5422c_level0_col0" class="col_heading level0 col0" >Países</th>
#       <th id="T_5422c_level0_col1" class="col_heading level0 col1" >Indicador de Corrupção</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5422c_level0_row0" class="row_heading level0 row0" >122</th>
#       <td id="T_5422c_row0_col0" class="data row0 col0" ><div style="text-align: left">Romania</div></td>
#       <td id="T_5422c_row0_col1" class="data row0 col1" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row1" class="row_heading level0 row1" >17</th>
#       <td id="T_5422c_row1_col0" class="data row1 col0" ><div style="text-align: left">Bosnia and Herzegovina</div></td>
#       <td id="T_5422c_row1_col1" class="data row1 col1" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_5422c_row2_col0" class="data row2 col0" ><div style="text-align: left">Bulgaria</div></td>
#       <td id="T_5422c_row2_col1" class="data row2 col1" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row3" class="row_heading level0 row3" >35</th>
#       <td id="T_5422c_row3_col0" class="data row3 col0" ><div style="text-align: left">Croatia</div></td>
#       <td id="T_5422c_row3_col1" class="data row3 col1" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row4" class="row_heading level0 row4" >155</th>
#       <td id="T_5422c_row4_col0" class="data row4 col0" ><div style="text-align: left">Ukraine</div></td>
#       <td id="T_5422c_row4_col1" class="data row4 col1" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row5" class="row_heading level0 row5" >64</th>
#       <td id="T_5422c_row5_col0" class="data row5 col0" ><div style="text-align: left">Indonesia</div></td>
#       <td id="T_5422c_row5_col1" class="data row5 col1" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row6" class="row_heading level0 row6" >96</th>
#       <td id="T_5422c_row6_col0" class="data row6 col0" ><div style="text-align: left">Moldova</div></td>
#       <td id="T_5422c_row6_col1" class="data row6 col1" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row7" class="row_heading level0 row7" >150</th>
#       <td id="T_5422c_row7_col0" class="data row7 col0" ><div style="text-align: left">Trinidad and Tobago</div></td>
#       <td id="T_5422c_row7_col1" class="data row7 col1" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row8" class="row_heading level0 row8" >85</th>
#       <td id="T_5422c_row8_col0" class="data row8 col0" ><div style="text-align: left">Lithuania</div></td>
#       <td id="T_5422c_row8_col1" class="data row8 col1" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_5422c_level0_row9" class="row_heading level0 row9" >120</th>
#       <td id="T_5422c_row9_col0" class="data row9 col0" ><div style="text-align: left">Portugal</div></td>
#       <td id="T_5422c_row9_col1" class="data row9 col1" >0.92</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#         <div style="width:50%;">
#             <style type="text/css">
# #T_de066 caption {
#   font-size: 130%;
#   font-weight: bold;
# }
# #T_de066 th {
#   text-align: left;
# }
# </style>
# <table id="T_de066">
#   <caption>Países com as <span style = 'color: red'> piores </span> médias de Corrupção</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de066_level0_col0" class="col_heading level0 col0" >Países</th>
#       <th id="T_de066_level0_col1" class="col_heading level0 col1" >Indicador de Corrupção</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de066_level0_row0" class="row_heading level0 row0" >86</th>
#       <td id="T_de066_row0_col0" class="data row0 col0" ><div style="text-align: left">Luxembourg</div></td>
#       <td id="T_de066_row0_col1" class="data row0 col1" >0.38</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row1" class="row_heading level0 row1" >60</th>
#       <td id="T_de066_row1_col0" class="data row1 col0" ><div style="text-align: left">Hong Kong S.A.R. of China</div></td>
#       <td id="T_de066_row1_col1" class="data row1 col1" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row2" class="row_heading level0 row2" >111</th>
#       <td id="T_de066_row2_col0" class="data row2 col0" ><div style="text-align: left">Norway</div></td>
#       <td id="T_de066_row2_col1" class="data row2 col1" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row3" class="row_heading level0 row3" >143</th>
#       <td id="T_de066_row3_col0" class="data row3 col0" ><div style="text-align: left">Switzerland</div></td>
#       <td id="T_de066_row3_col1" class="data row3 col1" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row4" class="row_heading level0 row4" >142</th>
#       <td id="T_de066_row4_col0" class="data row4 col0" ><div style="text-align: left">Sweden</div></td>
#       <td id="T_de066_row4_col1" class="data row4 col1" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row5" class="row_heading level0 row5" >105</th>
#       <td id="T_de066_row5_col0" class="data row5 col0" ><div style="text-align: left">New Zealand</div></td>
#       <td id="T_de066_row5_col1" class="data row5 col1" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row6" class="row_heading level0 row6" >47</th>
#       <td id="T_de066_row6_col0" class="data row6 col0" ><div style="text-align: left">Finland</div></td>
#       <td id="T_de066_row6_col1" class="data row6 col1" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row7" class="row_heading level0 row7" >39</th>
#       <td id="T_de066_row7_col0" class="data row7 col0" ><div style="text-align: left">Denmark</div></td>
#       <td id="T_de066_row7_col1" class="data row7 col1" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row8" class="row_heading level0 row8" >124</th>
#       <td id="T_de066_row8_col0" class="data row8 col0" ><div style="text-align: left">Rwanda</div></td>
#       <td id="T_de066_row8_col1" class="data row8 col1" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_de066_level0_row9" class="row_heading level0 row9" >129</th>
#       <td id="T_de066_row9_col0" class="data row9 col0" ><div style="text-align: left">Singapore</div></td>
#       <td id="T_de066_row9_col1" class="data row9 col1" >0.15</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>
#     </div>
